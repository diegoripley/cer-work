# %% [markdown]
# # Work Done
# - 2016 FSA boundaries are available [here](https://www12.statcan.gc.ca/census-recensement/2011/geo/bound-limit/bound-limit-2016-eng.cfm)
# - Signed up for Planet basemap trial. Trial ends October 20, 2020.
#   - Trial offers access to selected imagery and time periods (ex. State of California)

# %% [markdown]
# # Planet

# %% [markdown]
# - [Python API Client](https://github.com/planetlabs/planet-client-python)
#
# ```
# pip install planet
# ```

# %%
import os
import json
import pandas as pd

from planet import api

# %%
from IPython.core.display import display

# %%
# https://planetlabs.github.io/planet-client-python/api/examples.html#creating-a-client
os.environ['PL_API_KEY'] = '668057cc3483485bafdb759d2ad7e1b8'
client = api.ClientV1()

# %%
results = []

# %%
aoi = {
  "type": "Polygon",
  "coordinates": [
          [
            [
              -114.3511962890625,
              50.89826933991605
            ],
            [
              -113.81698608398438,
              50.89826933991605
            ],
            [
              -113.81698608398438,
              51.223227728996164
            ],
            [
              -114.3511962890625,
              51.223227728996164
            ],
            [
              -114.3511962890625,
              50.89826933991605
            ]
          ]
    ]
}

# %%
aoi = {
        "type": "Point",
        "coordinates": [
          -116.18953,
          49.01953
        ]
}

# %%
# build a filter for the AOI
query = api.filters.and_filter(
  api.filters.geom_filter(aoi)
)
# we are requesting PlanetScope 4 Band imagery
item_types = ['PSScene4Band']
request = api.filters.build_search_request(query, item_types)
# this will cause an exception if there are any API related errors
results = client.quick_search(request)

df = pd.DataFrame.from_dict(results)
"""
# items_iter returns an iterator over API response pages
#for item in results.items_iter(10):
  # each item is a GeoJSON feature
  df = pd.DataFrame.from_dict(data=item['properties'])
  #pd.DataFrame(item['properties'])
  #print(item['properties'])
  print(df)
"""
# Out:
# "\n# items_iter returns an iterator over API response pages\n#for item in results.items_iter(10):\n  # each item is a GeoJSON feature\n  df = pd.DataFrame.from_dict(data=item['properties'])\n  #pd.DataFrame(item['properties'])\n  #print(item['properties'])\n  print(df)\n"

# %%
for x in results.items_iter(1):
    properties = x['properties']
    df = pd.DataFrame.from_dict(data=[properties])
    #display(df)
    #df.to_csv('test.csv')
    df.transpose()
    display(df)
# Out:
#                       acquired  anomalous_pixels  clear_confidence_percent  \
# 0  2020-10-20T18:01:22.088709Z                 0                        69
#
#    clear_percent  cloud_cover  cloud_percent  columns  epsg_code  \
# 0             39         0.02             48    12708      32611
#
#    ground_control  gsd  ...  satellite_id shadow_percent snow_ice_percent  \
# 0            True  3.9  ...          222f              5                0
#
#    strip_id  sun_azimuth  sun_elevation               updated view_angle  \
# 0   3827038        155.3           27.2  2020-10-21T10:09:19Z          1
#
#   visible_confidence_percent visible_percent
# 0                         58              52
#
# [1 rows x 33 columns]

# %% [markdown]
# # Planet API
# {
#    "_links": {
#       "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20201004_183901_0f4e",
#       "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20201004_183901_0f4e/assets/",
#       "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20201004_183901_0f4e/thumb"
#    },
#    "_permissions": [],
#    "geometry": {
#       "coordinates": [],
#       "type": "Polygon"
#    },
#    "id": "20201004_183901_0f4e",
#    "properties": {
#       "acquired": "2020-10-04T18:39:01.800918Z",
#       "anomalous_pixels": 0,
#       "clear_confidence_percent": 90,
#       "clear_percent": 43,
#       "cloud_cover": 0.61,
#       "cloud_percent": 57,
#       "columns": 8941,
#       "epsg_code": 32610,
#       "ground_control": true,
#       "gsd": 3.9,
#       "heavy_haze_percent": 0,
#       "instrument": "PS2",
#       "item_type": "PSScene4Band",
#       "light_haze_percent": 0,
#       "origin_x": 519000,
#       "origin_y": 4198281,
#       "pixel_resolution": 3,
#       "provider": "planetscope",
#       "published": "2020-10-05T05:22:58Z",
#       "publishing_stage": "finalized",
#       "quality_category": "standard",
#       "rows": 4488,
#       "satellite_azimuth": 180.4,
#       "satellite_id": "0f4e",
#       "shadow_percent": 0,
#       "snow_ice_percent": 0,
#       "strip_id": "3783038",
#       "sun_azimuth": 152,
#       "sun_elevation": 43.5,
#       "updated": "2020-10-05T10:09:15Z",
#       "view_angle": 1.6,
#       "visible_confidence_percent": 72,
#       "visible_percent": 43
#    },
#    "type": "Feature"
# }

# %%
df.head()
# Out:
#                                                    0
# 0  b'{"_links": {"_first": "https://api.planet.co...
# 1  b'blishing_stage": "finalized", "quality_categ...
# 2  b'ed", "quality_category": "test", "rows": 773...
# 3  b'.134668315745024], [-116.39189833489424, 49....
# 4  b'nt": 0, "strip_id": "3657647", "sun_azimuth"...

# %% [markdown]
# # Sentinnel
# ```
# conda install -c conda-forge sentinelhub
# ```

# %%
import geopandas as gpd
import sqlalchemy

# %%
connection_string = 'postgresql://warehouse:GTgbLmFcbfkcAPmZVVax5Ezxt4@10.1.10.105:6001/warehouse'
engine = sqlalchemy.create_engine(connection_string)

# %%
"""
CREATE TABLE pipelines_buffer 
    AS SELECT objectid, status, age, substance, company, 
    ST_Buffer(ST_Transform(shape, 4326)::geography, 75000)::geometry 
FROM pipelines;
"""
# Out:
# '\nCREATE TABLE pipelines_buffer \n    AS SELECT objectid, status, age, substance, company, \n    ST_Buffer(ST_Transform(shape, 4326)::geography, 75000)::geometry \nFROM pipelines;\n'

# %%
pipelines = gpd.read_postgis('', engine, geom_col='shape')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#
# /opt/conda/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute_no_params(self, cursor, statement, context)
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#
# SyntaxError: syntax error at or near "pipelines"
# LINE 1: pipelines
#         ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...

# %%
pipelines['status'].value_counts()
# Out:
# Operating         2685
# Abandoned           95
# Decommissioned      79
# Deactivated         77
# Approved            58
# Name: status, dtype: int64

# %%
latest high resolution imagery for pipeline 203
# Out:
#   File "<ipython-input-30-20fd5d35be99>", line 1
#     latest high resolution imagery for pipeline 203
#            ^
# SyntaxError: invalid syntax
